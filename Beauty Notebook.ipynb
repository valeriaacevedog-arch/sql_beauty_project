# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-1.0.0-py3-none-any.whl.metadata (40 kB)
# Collecting kagglesdk<1.0,>=0.1.14 (from kagglehub)
#   Downloading kagglesdk-0.1.16-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /opt/anaconda3/lib/python3.13/site-packages (from kagglehub) (25.0)
# Requirement already satisfied: pyyaml in /opt/anaconda3/lib/python3.13/site-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.13/site-packages (from kagglehub) (2.32.5)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.13/site-packages (from kagglehub) (4.67.1)
# Requirement already satisfied: protobuf in /opt/anaconda3/lib/python3.13/site-packages (from kagglesdk<1.0,>=0.1.14->kagglehub) (5.29.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kagglehub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kagglehub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kagglehub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.13/site-packages (from requests->kagglehub) (2025.11.12)
# Downloading kagglehub-1.0.0-py3-none-any.whl (70 kB)
# Downloading kagglesdk-0.1.16-py3-none-any.whl (160 kB)
# Installing collected packages: kagglesdk, kagglehub
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [kagglehub]/2 [kagglehub]
# Successfully installed kagglehub-1.0.0 kagglesdk-0.1.16

# %%
import kagglehub
path = kagglehub.dataset_download("waqi786/most-used-beauty-cosmetics-products-in-the-world")

print("Path to dataset files:", path)
# Out:
# Downloading to /Users/valeriaacevedo/.cache/kagglehub/datasets/waqi786/most-used-beauty-cosmetics-products-in-the-world/1.archive...
# 100%|██████████| 315k/315k [00:00<00:00, 3.34MB/s]
# Extracting files...
# Path to dataset files: /Users/valeriaacevedo/.cache/kagglehub/datasets/waqi786/most-used-beauty-cosmetics-products-in-the-world/versions/1

# %%
from pathlib import Path
from tqdm import tqdm

# %%
dataset_dir = Path("/Users/valeriaacevedo/.cache/kagglehub/datasets/waqi786/most-used-beauty-cosmetics-products-in-the-world/versions/1")
csv_path = next(dataset_dir.glob("*.csv"))
